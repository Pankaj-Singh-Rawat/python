# %%
from http.cookiejar import cut_port_re

# Input: s = "abcabcbb"
# Output: 3
# Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.

s = "pwawkew"
def lengthOfLongestSubstring(s: str ) -> int:
    seen = set()
    left = 0
    max_Value = 0

    for i in range(len(s)):
        while s[i] in seen:
            seen.remove(s[left])
            left += 1

        seen.add(s[i])
        max_Value = max(max_Value, i - left + 1)

    return max_Value

print(lengthOfLongestSubstring(s))

# %%
# Input: s = "babad"
# Output: "bab"
# Explanation: "aba" is also a valid answer.
def longestPalindrome(s: str) -> str:
    final_max = 0
    start = 0
    for i in range(len(s)):

        len1 = doThis(s, i, i)
        len2 = doThis(s, i, i + 1)

        current_max = max(len1 , len2)

        if current_max > final_max:
            final_max = current_max

            start = i - (current_max - 1)//2

    return s[start: start + final_max]

def doThis(s: str, left: int, right: int) -> int:

    while left >= 0 and right < len(s) and s[left] == s[right]:
        left -= 1
        right += 1

    return right - left - 1

s = "babad"
print(longestPalindrome(s))

# %%
def rotate(nums: list[int], k: int) -> list:
        """
        Do not return anything, modify nums in-place instead.
        """
        k %= len(nums)
        nums.reverse()
        nums[:k] = reversed(nums[:k])
        nums[k:] = reversed(nums[k:])
        return nums

s = [1,2,3,4,5,6,7]
k = 20
print(rotate(s, k))

# %%
# 20. Valid Parentheses
class Solution:
    def isValid(self, s: str) -> bool:
        my_dict = {')' : '(', ']' : '[', '}' : '{'}
        my_stack = []
        for char in s:
            if char in my_dict:
                last_element = my_stack.pop() if my_stack else '#'

                if my_dict[char] != last_element:
                    return False
            else:
                my_stack.append(char)
        return len(my_stack) == 0

# %%
# 155. MinStack
class MinStack:

    def __init__(self):
        self.stack = []
        self.minStack = []

    def push(self, val: int) -> None:
        self.stack.append(val)
        if not self.minStack or self.minStack[-1] >= val:
            self.minStack.append(val)


    def pop(self) -> None:
        if self.minStack[-1] == self.stack[-1]:
            self.minStack.pop()
        self.stack.pop()


    def top(self) -> int:
        return self.stack[-1]

    def getMin(self) -> int:
        return self.minStack[-1]

# %%
# Input: s = "3[a2[bc]]"
# Output: "accaccacc"
# "aaabcbc"
def decodeString(s: str) -> str:
    storage = ""
    num = 0
    mystack = []

    for char in s:
        if char.isdigit():
            num = num * 10 + int(char)
        elif char == '[':
            mystack.append((storage, num))
            storage = ""
            num = 0
        elif char == ']':
            last, repeat = mystack.pop()
            storage = last + (repeat * storage)

        else:
            storage += char
            
        
    return storage

s = "3[a]2[bc]"
print(decodeString(s))

# %%
# Input: s = "(1+(4+5+2)-3)+(6+8)"
# Output: 23
# s consists of digits, '+', '-', '(', ')', and ' '.


def calculate(self, s: str) -> int:
    mystack = []
    calc = 0
    sign = 1    
    number = 0
    i = 0
    for char in s:
        if char.isdigit():
            number = number*10 + int(char)
        elif char == '+':
            calc += sign * number
            number = 0
            sign = 1
        elif char == '-':
            calc += sign * number
            number = 0
            sign = -1
        elif char == '(':  
            mystack.append((calc, sign))
            calc = 0
            sign = 1
        elif char == ')':
            calc += sign * number
            number = 0
            last_calc, last_sign = mystack.pop
            calc *= last_sign
            calc += last_calc
        
        return calc + (sign * number)

# %%
# Input: nums1 = [4,1,2], nums2 = [1,3,4,2]
# Output: [-1,3,-1]

def nextGreaterElement(self, nums1: List[int], nums2: List[int]) -> List[int]:
    mystack = []
    greaterElement = {}
    i = 0
    for num in nums2:

        while mystack and num > mystack[-1]:
            lesserNum = mystack.pop()
            greaterElement[lesserNum] = num

        mystack.append(num)
    return [greaterElement.get(n, -1) for n in nums1]

# %%
def dailyTemperatures(temperatures: list[int]) -> list[int]:
# Input: temperatures = [73,74,75,71,69,72,76,73]
# Output: [1,1,4,2,1,1,0,0]

    n = len(temperatures)
    ansStack = [0] * n
    myStack = []
    for i in range(n):
        while myStack and temperatures[i] > temperatures[myStack[-1]]:
            prev_stack_index = myStack.pop()
            ansStack[prev_stack_index] = i - prev_stack_index

        myStack.append(i)

    return ansStack

temperatures = [73,74,75,71,69,72,76,73]
print(dailyTemperatures(temperatures))

# %%
# LC - 2396 -> return False
def isStrictlyPalindromic(self, n: int) -> bool:
    return False
# LC - 877 -> return True
def stoneGame(self, piles: List[int]) -> bool:
    return True

# LC - 319 -> return int(n**0.5)
def bulbSwitch(self, n: int) -> int:
    return int(n**0.5)

# LC - 771 -> return sum(s in jewels for s in stones)
def numJewelsInStones(self, jewels: str, stones: str) -> int:
    return sum(s in jewels for s in stones)

# %%
def trap(h: list[int]) -> int:
    if not h : return 0
    
    highestValue = max(h)
    index_of_highest_value = h.index(highestValue)

    left = 0
    right = 1
    maxx = 0
    while right <= index_of_highest_value:
        if h[left] <= h[right]:
            maxx += calculategaddha(h, left, right)
            left = right
        right += 1

    right_p = len(h) - 1
    left_p = right_p - 1
    while left_p >= index_of_highest_value:
        if h[right_p] <= h[left_p]:
            maxx += calculategaddha_reverse(h, left_p, right_p)
            right_p = left_p
        left_p -= 1

    return maxx

def calculategaddha(h: list[int], left: int, right: int) -> int:
    water = 0
    for i in range(left + 1, right):
        water += h[left] - h[i]
    return water


def calculategaddha_reverse(h: list[int], left: int, right: int) -> int:
    water = 0
    for i in range(left + 1, right):
        water += h[right] - h[i]
    return water


print(trap([0,1,0,2,1,0,1,3,2,1,2,1]))

# %%
# LC - 27
def removeElement(nums: list[int], val: int) -> list:
    left = 0 
    right = 0
    while left < len(nums):
        if val != nums[left]:
            nums[right] = nums[left]
            right += 1
        left += 1
    
    return nums

print(removeElement([0,1,2,2,3,0,4,2], 2))

# %%
# 237. Delete Node in a Linked List
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def deleteNode(self, node):
        """
        :type node: ListNode
        :rtype: void Do not return anything, modify node in-place instead.
        """

        node.val = node.next.val
        node.next = node.next.next

# --- TESTING UTILITIES ---

def build_linked_list(arr):
    if not arr: return None
    head = ListNode(arr[0])
    curr = head
    for i in range(1, len(arr)):
        curr.next = ListNode(arr[i])
        curr = curr.next
    return head

def get_node_by_val(head, val):
    curr = head
    while curr:
        if curr.val == val:
            return curr
        curr = curr.next
    return None

def print_list(head):
    res = []
    curr = head
    while curr:
        res.append(curr.val)
        curr = curr.next
    print(res)

# --- EXECUTION ---

# 1. Create the list [4, 5, 1, 9]
head = build_linked_list([4, 5, 1, 9])

# 2. Get the reference to the node with value 5
node_to_delete = get_node_by_val(head, 5)

# 3. Run your solution
sol = Solution()
sol.deleteNode(node_to_delete)

# 4. Check the result (Expected: [4, 1, 9])
print_list(head)

# %%
# 876. Middle of the Linked List
def middleNode(self, head: Optional[ListNode]) -> Optional[ListNode]:

    current = head
    size = 0
    while current:
        size += 1
        current = current.next
    
    target = (size//2) + 1

    current = head
    while current:
        if target == 1:
            head = current
            return head
        
        target -= 1
        current = current.next

# %%
# 206. Reverse Linked List
def reverseList(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if head == None:
            return head
        current = head
        prev = None
        while current:
            nextt = current.next
            current.next = prev
            prev = current
            current = nextt
        
        return prev

# %%
# 21. Merge Two Sorted Lists
def mergeTwoLists(self, list1: Optional[ListNode], list2: Optional[ListNode]) -> Optional[ListNode]:
    
    dummy = ListNode(0)
    curr = dummy

    while list1 and list2:
        if list1.val <= list2.val:
            curr.next = list1
            list1 = list1.next
        else:
            curr.next = list2
            list2 = list2.next
        curr = curr.next

    curr.next = list1 if list1 else list2

    return dummy.next

# %%
# 19. Remove Nth Node From End of List
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeNthFromEnd(self, head: Optional[ListNode], n: int) -> Optional[ListNode]:
        curr = head
        size = 0
        while curr:
            size += 1
            curr = curr.next
        
        curr = head

        if size == n:
            return curr.next

        for _ in range(size - n - 1):
            curr = curr.next
        
        curr.next = curr.next.next
        return head

# %%
# 141. Linked List Cycle
class Solution:
    def hasCycle(self, head: Optional[ListNode]) -> bool:
        slow = fast = head
        while fast and fast.next:
            slow, fast = slow.next, fast.next.next
            if slow == fast:
                return True
        return False

# %%
# 19. Remove Nth Node From End of List
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def removeNthFromEnd(self, head: Optional[ListNode], n: int) -> Optional[ListNode]:
        curr = head
        size = 0
        while curr:
            size += 1
            curr = curr.next
        
        curr = head

        if size == n:
            return curr.next

        for _ in range(size - n - 1):
            curr = curr.next
        
        curr.next = curr.next.next
        return head

# %%
# 234. Palindrome Linked List
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def isPalindrome(self, head: Optional[ListNode]) -> bool:

        slow = fast = head

        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
        
        prev = None
        while slow:
            nextt = slow.next
            slow.next = prev
            prev = slow
            slow = nextt

        left, right = head, prev

        while right:
            if right.val != left.val:
                return False
            right = right.next
            left = left.next
        
        return True

# %%
# 83. Remove Duplicates from Sorted List
class Solution:
    def deleteDuplicates(self, head: Optional[ListNode]) -> Optional[ListNode]:
        if head == None:
            return head
            
        curr = start = head
        while curr and curr.next:
            if curr.val != curr.next.val:
                start.next = curr.next
                start = start.next
            
            curr = curr.next
        
        start.next = None
        return head

# %%
# LC - 33
def search(nums: list[int], target: int) -> int:
    left = 0 
    right = len(nums) - 1

    while left <= right:
        mid =left + (right - left)//2

        if target == nums[mid]:
            return mid
        elif nums[left] <= nums[mid]:
            if nums[left] <= target < nums[mid]:
                right = mid - 1
            else:
                left = mid + 1
        else:
            if nums[right] >= target > nums[mid]:
                left = mid + 1
            else:
                right = mid - 1

    return -1

print(search([4,5,6,7,0,1,2], 0))
