# %%
import numpy as np
from numpy import random

# %%
print(random.randint(100))
# Out:
# 74

# %%
print(random.rand())
# Out:
# 0.15855582489280817

# %%
print(random.randint(1000))
# Out:
# 477

# %%
# Generate a 1-D array containing 5 random integers from 0 to 100
x=random.randint(100, size=(5))
print(x)
# Out:
# [53 70 43 61 34]

# %%
x = random.randint(100, size=(3, 5))
print(x)
# Out:
# [[82 25 71 57 29]
#  [ 6 65  8 34 32]
#  [79 68 79 87 40]]

# %%
x = random.rand(3,5)
print(x)
# Out:
# [[0.30207978 0.16329256 0.5075645  0.85094748 0.23494428]
#  [0.23087348 0.5714668  0.94509629 0.6634366  0.06836882]
#  [0.1370211  0.70324684 0.97504157 0.26075942 0.62653144]]

# %%
print(random.choice([1,2,3,4,5]))
# Out:
# 3

# %%
x = random.choice([1,2,3,4,5], size=(3,5))
print(x)
# Out:
# [[4 1 1 5 1]
#  [5 1 5 2 2]
#  [2 1 4 4 4]]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))
print(x)
# Out:
# [7 5 7 7 5 5 7 7 7 7 3 7 3 7 5 7 5 5 7 5 3 7 7 7 7 5 7 7 5 5 5 7 7 5 7 7 5
#  7 7 7 7 5 5 3 3 5 5 7 5 5 7 5 3 5 7 5 3 5 5 5 7 5 7 7 5 3 7 7 7 7 5 5 5 5
#  7 3 3 7 7 5 7 7 5 7 7 5 3 7 7 5 7 7 3 5 7 7 7 7 7 7]

# %%
x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3,5))
print(x)
# Out:
# [[7 3 5 7 7]
#  [7 7 7 5 7]
#  [5 3 5 5 7]]

# %%
x = [1,2,3,4,5]
random.shuffle(x)
print(x)
# Out:
# [2, 1, 3, 4, 5]

# %%
print(random.permutation(x))
# Out:
# [2 4 5 1 3]

# %%
# Seaborn
! pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/psr/Documents/python/.venv/lib/python3.12/site-packages (from seaborn) (2.4.2)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-3.0.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Downloading matplotlib-3.10.8-cp312-cp312-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading fonttools-4.61.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/psr/Documents/python/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Collecting pillow>=8 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pillow-12.1.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/psr/Documents/python/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/psr/Documents/python/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading matplotlib-3.10.8-cp312-cp312-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 4.7 MB/s eta 0:00:00a 0:00:01m
# Downloading contourpy-1.3.3-cp312-cp312-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp312-cp312-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 1.9 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.4.9-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
# Downloading pandas-3.0.0-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading pillow-12.1.0-cp312-cp312-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, pandas, matplotlib, seaborn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [seaborn]m8/9 [seaborn]ib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pandas-3.0.0 pillow-12.1.0 pyparsing-3.3.2 seaborn-0.13.2
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import seaborn as sns

# %%
sns.displot([0,1,2,3,4,5])
plt.show()

# %%
# plotting a displot without the histogram
sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

# %%
# Normal Distribution
"""loc - (Mean) where the peak of the bell exists.

scale - (Standard Deviation) how flat the graph distribution should be.

size - The shape of the returned array.
"""
# noraml() -> normal data distribution
x = random.normal(size = (2,3))
print(x)
# Out:
# [[ 0.0848364   0.62440712 -0.43653856]
#  [ 0.68438514 -0.29051921  0.06503692]]

# %%
sns.displot(random.normal(size=1000), kind = "kde")

# %%
# Binomial Distribution
"""
n - number of trials.

p - probability of occurrence of each trial (e.g. for toss of a coin 0.5 each).

size - The shape of the returned array.

"""
print(random.binomial(10, p=0.5, size = 10))
# Out:
# [4 3 3 5 5 6 4 5 6 4]

# %%
sns.displot(random.binomial(n = 10, p = 0.5, size = 1000))

# %%
data = {
  "normal": random.normal(loc=50, scale=5, size=1000),
  "binomial": random.binomial(n=100, p=0.5, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
def isPowerOfThree( n):
    count = 0
    while (n > 3**count):
        count+=1
    return count

print(isPowerOfThree(27))
# Out:
# 3

# %%
def mySqrt(n):
    left = 0
    right = n 
    while left <= right:
        mid = left + (right - left)//2
        num = mid * mid
        if num == n:
            return mid
        elif num < n:
            left = mid + 1
        else:
            right = mid - 1
    
    return right

print(mySqrt(8))
# Out:
# 2
